# %%
from bloqade.analog import load, save
from bloqade.analog.atom_arrangement import Square
import numpy as np
import os
import matplotlib.pyplot as plt
from bloqade.analog import get_capabilities
import qbraid

api_key="bebf965df8184697aa6dd8e571a845b3"

provider = qbraid.QbraidProvider(api_key=api_key)
provider.save_config()
provider = qbraid.QbraidProvider()
provider.get_devices()


from bokeh.io import output_notebook
output_notebook() 

if not os.path.isdir("data"):
    os.mkdir("data")

# setting the seed
rng = np.random.default_rng(1234)
# a=5
# lattice =Square(4, lattice_spacing=a).apply_defect_density(0.3, rng=rng).remove_vacant_sites()

from bloqade.analog import start



def run_rydberg(points):
    geometry = start.add_position(points)

    #durations = [0.3, 1.6, 0.3]

    # lattice.show()
    # geometry.show()

    # get capabilities for Aquila
    aquila_capabilities = get_capabilities()

    C6=float(aquila_capabilities.capabilities.rydberg.c6_coefficient)
    Omega_max= float(aquila_capabilities.capabilities.rydberg.global_.rabi_frequency_max) #2*np.pi*4 #

    Rba=np.power(2,3/4)
    Rb=Rba*a
    print(Rb)
    # Rb=12

    Delta_end= (C6)/Rb**6 #final detuning 2*np.pi*11

    RbO=(C6/Omega_max)**(1/6)
    RbD=(C6/Delta_end)**(1/6)

    from bloqade.analog import piecewise_linear

    T_max=4
    sweep_time = 0.8*T_max #time length of the protocol 
    ramp_time=0.1*T_max

    rabi_amplitude_values = [0.0, Omega_max, Omega_max, 0.0]
    detuning_values = [-Delta_end, -Delta_end, Delta_end, Delta_end]
    durations = [ramp_time, sweep_time, ramp_time]

    RabiProtocol = piecewise_linear(durations,rabi_amplitude_values)
    DeltaProtocol = piecewise_linear(durations,detuning_values)

    # RabiProtocol.show()
    # DeltaProtocol.show()

    mis_udg_program=(
            # lattice.rydberg.rabi.amplitude.uniform.apply(RabiProtocol)
            # .detuning.uniform.apply(DeltaProtocol)
            geometry.rydberg.rabi.amplitude.uniform.apply(RabiProtocol).detuning.uniform.apply(DeltaProtocol)
    )

    result = mis_udg_program.parallelize(24).braket.aquila().run(100,interaction_picture=True)


    report = result.report()
    # report.show()

    data = result.report().bitstrings()

    temp = [0]*len(points)
    for i in range(len(data[0])):
        temp += data[0][i]

    # make values greater than 50 into 1, and less than 50 into 0
    # temp = [1 if x > 8200 else 0 for x in temp]
    temp = [float(x/10000) for x in temp]
    temp

    bitstrings, counts = np.unique(data[0], axis=0, return_counts=True)


    #get index of the maximum value in counts
    max = bitstrings[np.argmax(counts)]
    inv = [1 if x == 0 else 0 for x in max]
    # make a dictionary mapping the values in env to their sam indexed coordinates in points
    mapping = {i: points[i] for i in range(len(points))}
    mapping

    # inv 
    print(points)
    print(inv)

    max_set = [cordinate for i, cordinate in enumerate(points) if inv[i] == 1]
    remaining_set = [cordinate for i, cordinate in enumerate(points) if inv[i] == 0]

    if not max_set:
        max_set = remaining_set
        remaining_set = []

    return remaining_set, max_set
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[10], line 11
#       7 import qbraid
#       9 api_key="bebf965df8184697aa6dd8e571a845b3"
# ---> 11 provider = qbraid.QbraidProvider(api_key=api_key)
#      12 provider.save_config()
#      13 provider = qbraid.QbraidProvider()
#
# File ~/anaconda3/envs/yqh/lib/python3.12/site-packages/qbraid/__init__.py:151, in __getattr__(name)
#     148     return module
#     150 if name in objects:
# --> 151     module = importlib.import_module(f".{mod_name}", __name__)
#     152     obj = getattr(module, name)
#     153     globals()[name] = obj
#
# File ~/anaconda3/envs/yqh/lib/python3.12/importlib/__init__.py:90, in import_module(name, package)
#      88             break
#      89         level += 1
# ---> 90 return _bootstrap._gcd_import(name[level:], package, level)
#
# File <frozen importlib._bootstrap>:1387, in _gcd_import(name, package, level)
#
# File <frozen importlib._bootstrap>:1360, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:1331, in _find_and_load_unlocked(name, import_)
#
# File <frozen importlib._bootstrap>:935, in _load_unlocked(spec)
#
# File <frozen importlib._bootstrap_external>:999, in exec_module(self, module)
#
# File <frozen importlib._bootstrap>:488, in _call_with_frames_removed(f, *args, **kwds)
#
# File ~/anaconda3/envs/yqh/lib/python3.12/site-packages/qbraid/runtime/__init__.py:94
#      92 from .profile import TargetProfile
#      93 from .provider import QuantumProvider
# ---> 94 from .result import Result
#      95 from .result_data import (
#      96     AhsResultData,
#      97     AhsShotResult,
#    (...)    100     ResultData,
#     101 )
#     103 PROVIDERS = get_providers()
#
# File ~/anaconda3/envs/yqh/lib/python3.12/site-packages/qbraid/runtime/result.py:25
#      22 from qbraid_core import deprecated
#      23 from qbraid_core.system.generic import _datetime_to_str
# ---> 25 from .result_data import ResultDataType
#      28 class Result(Generic[ResultDataType]):
#      29     """Represents the results of a quantum job. This class is intended
#      30     to be initialized by a QuantumJob class.
#      31
#    (...)     38
#      39     """
#
# File ~/anaconda3/envs/yqh/lib/python3.12/site-packages/qbraid/runtime/result_data.py:26
#      23 from qbraid.programs import ExperimentType
#      25 from .postprocess import counts_to_probabilities, normalize_counts
# ---> 26 from .schemas.experiment import (
#      27     AhsExperimentMetadata,
#      28     AnnealingExperimentMetadata,
#      29     ExperimentMetadata,
#      30     GateModelExperimentMetadata,
#      31 )
#      33 ResultDataType = TypeVar("ResultDataType", bound="ResultData")
#      35 KeyType = TypeVar("KeyType", str, int)
#
# File ~/anaconda3/envs/yqh/lib/python3.12/site-packages/qbraid/runtime/schemas/__init__.py:47
#      11 """
#      12 Module defining qBraid runtime schemas.
#      13
#    (...)     44
#      45 """
#      46 from .base import USD, Credits, QbraidSchemaBase, QbraidSchemaHeader
# ---> 47 from .device import DeviceData, DevicePricing
#      48 from .experiment import (
#      49     AhsExperimentMetadata,
#      50     AnnealingExperimentMetadata,
#    (...)     55     QuEraQasmSimulationMetadata,
#      56 )
#      57 from .job import RuntimeJobModel, TimeStamps
#
# File ~/anaconda3/envs/yqh/lib/python3.12/site-packages/qbraid/runtime/schemas/device.py:22
#      17 from pydantic import BaseModel, ConfigDict, Field, field_serializer
#      19 from .base import USD, Credits
# ---> 22 class DevicePricing(BaseModel):
#      23     """Represents pricing information for a quantum device.
#      24
#      25     Attributes:
#    (...)     28         perMinute (USD): The cost per minute in USD.
#      29     """
#      31     model_config = ConfigDict(frozen=True)
#
# File ~/anaconda3/envs/yqh/lib/python3.12/site-packages/pydantic/_internal/_model_construction.py:237, in ModelMetaclass.__new__(mcs, cls_name, bases, namespace, __pydantic_generic_metadata__, __pydantic_reset_parent_namespace__, _create_model_module, **kwargs)
#     233     set_model_mocks(cls)
#     234 else:
#     235     # Any operation that requires accessing the field infos instances should be put inside
#     236     # `complete_model_class()`:
# --> 237     complete_model_class(
#     238         cls,
#     239         config_wrapper,
#     240         raise_errors=False,
#     241         ns_resolver=ns_resolver,
#     242         create_model_module=_create_model_module,
#     243     )
#     245 if config_wrapper.frozen and '__hash__' not in namespace:
#     246     set_default_hash_func(cls, bases)
#
# File ~/anaconda3/envs/yqh/lib/python3.12/site-packages/pydantic/_internal/_model_construction.py:597, in complete_model_class(cls, config_wrapper, raise_errors, ns_resolver, create_model_module)
#     590 gen_schema = GenerateSchema(
#     591     config_wrapper,
#     592     ns_resolver,
#     593     typevars_map,
#     594 )
#     596 try:
# --> 597     schema = gen_schema.generate_schema(cls)
#     598 except PydanticUndefinedAnnotation as e:
#     599     if raise_errors:
#
# File ~/anaconda3/envs/yqh/lib/python3.12/site-packages/pydantic/_internal/_generate_schema.py:706, in GenerateSchema.generate_schema(self, obj)
#     703 schema = self._generate_schema_from_get_schema_method(obj, obj)
#     705 if schema is None:
# --> 706     schema = self._generate_schema_inner(obj)
#     708 metadata_js_function = _extract_get_pydantic_json_schema(obj)
#     709 if metadata_js_function is not None:
#
# File ~/anaconda3/envs/yqh/lib/python3.12/site-packages/pydantic/_internal/_generate_schema.py:984, in GenerateSchema._generate_schema_inner(self, obj)
#     982 if lenient_issubclass(obj, BaseModel):
#     983     with self.model_type_stack.push(obj):
# --> 984         return self._model_schema(obj)
#     986 if isinstance(obj, PydanticRecursiveRef):
#     987     return core_schema.definition_reference_schema(schema_ref=obj.type_ref)
#
# File ~/anaconda3/envs/yqh/lib/python3.12/site-packages/pydantic/_internal/_generate_schema.py:817, in GenerateSchema._model_schema(self, cls)
#     805     model_schema = core_schema.model_schema(
#     806         cls,
#     807         inner_schema,
#    (...)    813         ref=model_ref,
#     814     )
#     815 else:
#     816     fields_schema: core_schema.CoreSchema = core_schema.model_fields_schema(
# --> 817         {k: self._generate_md_field_schema(k, v, decorators) for k, v in fields.items()},
#     818         computed_fields=[
#     819             self._computed_field_schema(d, decorators.field_serializers)
#     820             for d in computed_fields.values()
#     821         ],
#     822         extras_schema=extras_schema,
#     823         extras_keys_schema=extras_keys_schema,
#     824         model_name=cls.__name__,
#     825     )
#     826     inner_schema = apply_validators(fields_schema, decorators.root_validators.values(), None)
#     827     inner_schema = apply_model_validators(inner_schema, model_validators, 'inner')
#
# File ~/anaconda3/envs/yqh/lib/python3.12/site-packages/pydantic/_internal/_generate_schema.py:1186, in GenerateSchema._generate_md_field_schema(self, name, field_info, decorators)
#    1179 def _generate_md_field_schema(
#    1180     self,
#    1181     name: str,
#    1182     field_info: FieldInfo,
#    1183     decorators: DecoratorInfos,
#    1184 ) -> core_schema.ModelField:
#    1185     """Prepare a ModelField to represent a model field."""
# -> 1186     common_field = self._common_field_schema(name, field_info, decorators)
#    1187     return core_schema.model_field(
#    1188         common_field['schema'],
#    1189         serialization_exclude=common_field['serialization_exclude'],
#    (...)   1193         metadata=common_field['metadata'],
#    1194     )
#
# File ~/anaconda3/envs/yqh/lib/python3.12/site-packages/pydantic/_internal/_generate_schema.py:1352, in GenerateSchema._common_field_schema(self, name, field_info, decorators)
#    1348         schema = self._apply_annotations(
#    1349             source_type, annotations + validators_from_decorators, transform_inner_schema=set_discriminator
#    1350         )
#    1351     else:
# -> 1352         schema = self._apply_annotations(
#    1353             source_type,
#    1354             annotations + validators_from_decorators,
#    1355         )
#    1357 # This V1 compatibility shim should eventually be removed
#    1358 # push down any `each_item=True` validators
#    1359 # note that this won't work for any Annotated types that get wrapped by a function validator
#    1360 # but that's okay because that didn't exist in V1
#    1361 this_field_validators = filter_field_decorator_info_by_field(decorators.validators.values(), name)
#
# File ~/anaconda3/envs/yqh/lib/python3.12/site-packages/pydantic/_internal/_generate_schema.py:2264, in GenerateSchema._apply_annotations(self, source_type, annotations, transform_inner_schema)
#    2259         continue
#    2260     get_inner_schema = self._get_wrapped_inner_schema(
#    2261         get_inner_schema, annotation, pydantic_js_annotation_functions
#    2262     )
# -> 2264 schema = get_inner_schema(source_type)
#    2265 if pydantic_js_annotation_functions:
#    2266     core_metadata = schema.setdefault('metadata', {})
#
# File ~/anaconda3/envs/yqh/lib/python3.12/site-packages/pydantic/_internal/_schema_generation_shared.py:83, in CallbackGetCoreSchemaHandler.__call__(self, source_type)
#      82 def __call__(self, source_type: Any, /) -> core_schema.CoreSchema:
# ---> 83     schema = self._handler(source_type)
#      84     if self._ref_mode == 'to-def':
#      85         ref = schema.get('ref')
#
# File ~/anaconda3/envs/yqh/lib/python3.12/site-packages/pydantic/_internal/_generate_schema.py:2243, in GenerateSchema._apply_annotations.<locals>.inner_handler(obj)
#    2242 def inner_handler(obj: Any) -> CoreSchema:
# -> 2243     schema = self._generate_schema_from_get_schema_method(obj, source_type)
#    2245     if schema is None:
#    2246         schema = self._generate_schema_inner(obj)
#
# File ~/anaconda3/envs/yqh/lib/python3.12/site-packages/pydantic/_internal/_generate_schema.py:880, in GenerateSchema._generate_schema_from_get_schema_method(self, obj, source)
#     878 else:
#     879     ref_mode = 'to-def'
# --> 880 schema = get_schema(
#     881     source, CallbackGetCoreSchemaHandler(self._generate_schema_inner, self, ref_mode=ref_mode)
#     882 )
#     883 if schema['type'] == 'definitions':
#     884     schema = self.defs.unpack_definitions(schema)
#
# File ~/anaconda3/envs/yqh/lib/python3.12/site-packages/qbraid/runtime/schemas/base.py:138, in USD.__get_pydantic_core_schema__(cls, source_type, handler)
#     133 @classmethod
#     134 def __get_pydantic_core_schema__(  # pylint: disable-next=unused-argument
#     135     cls, source_type: type, handler: GetCoreSchemaHandler
#     136 ) -> core_schema.CoreSchema:
#     137     """Provide Pydantic with a schema for the USD type."""
# --> 138     number_schema = core_schema.union_schema(
#     139         [
#     140             core_schema.int_schema(),
#     141             core_schema.float_schema(),
#     142             handler(Decimal),
#     143         ],
#     144         strict=False,
#     145         custom_error_type="usd_type",
#     146         custom_error_message="Input should be a number (int, float, or Decimal)",
#     147     )
#     149     # pylint: disable-next=unused-argument
#     150     def to_usd(value: Union[int, float, Decimal], info) -> "USD":
#
# TypeError: union_schema() got an unexpected keyword argument 'strict'

# %%
np.power(2,3/4)
# Out:
# np.float64(1.681792830507429)

# %% [markdown]
# # Main

# %%
a = 5
# a = 1 # a;ready scaled here

# mul;tiply all the points x5 
og_points = [(8,  5),  (7,  4),  (5,  4), (8,  3),  (4,  3),  (7,  3), (5,  2), (3,  2),  (7,  2),  (2,  2), (6,  3), (4,  1), (1,  1), (3,  1), (2,  0), (0,  0)]
og_points =  [(8, 0), (7, 1), (5, 1), (8, 2), (4, 2), (7, 2),(5, 3), (3, 3), (7, 3), (2, 3), (6, 2), (4, 4),(1, 4), (3, 4), (2, 5), (0, 5)]

og_points = [(x*a,y*a) for x,y in og_points] #TODO add back

points = og_points.copy()
coloring = []

while points:
    remaining_set, max_set = run_rydberg(points)
    points = remaining_set
    coloring.append(max_set)

# plot then colored graph
# fig, ax = plt.subplots()
print(coloring)
visualize_colored_groups(coloring)
# Out:
# 8.408964152537145
# [(40, 0), (35, 5), (25, 5), (40, 10), (20, 10), (35, 10), (25, 15), (15, 15), (35, 15), (10, 15), (30, 10), (20, 20), (5, 20), (15, 20), (10, 25), (0, 25)]
# [1, 0, 1, 0, 0, 0, 0, 0, 1, 1, 0, 1, 0, 0, 1, 1]
# 8.408964152537145
# [(35, 5), (40, 10), (20, 10), (35, 10), (25, 15), (15, 15), (30, 10), (5, 20), (15, 20)]
# [0, 1, 1, 0, 0, 0, 1, 1, 1]
# 8.408964152537145
# [(35, 5), (35, 10), (25, 15), (15, 15)]
# [1, 0, 1, 1]
# 8.408964152537145
# [(35, 10)]
# [1]
# [[(40, 0), (25, 5), (35, 15), (10, 15), (20, 20), (10, 25), (0, 25)], [(40, 10), (20, 10), (30, 10), (5, 20), (15, 20)], [(35, 5), (25, 15), (15, 15)], [(35, 10)]]

# %%
# main
import random

# points = [(0,0), (1,0), (0,1), (0,2), (1,3), (2,0), (2,2), (2,3), (3,0),(3,1), (3,2), (3,3)]
# Initial Points
og_points = [(0,0), (1,0), (0,1), (0,2), (3,2), (3,3)]
og_points = [(0,0), (1,0), (0,1), (0,2), (1,3), (2,0), (2,2), (2,3), (3,0),(3,1), (3,2), (3,3)]
# og_points = [(9.0, 0.0), (9.0, 9.0), (9.0, 22.5), (4.5, 4.5), (9.0, 31.5), (4.5, 18.0), (4.5, 27.0), (4.5, 40.5), (0.0, 13.5), (9.0, 49.5), (0.0, 27.0), (0.0, 36.0), (9.0, 58.5), (0.0, 45.0), (0.0, 54.0), (4.5, 63.0)]
# og_points = [(2.0, 0.0), (2.0, 2.0), (2.0, 5.0), (1.0, 1.0), (2.0, 7.0), (1.0, 4.0), (1.0, 6.0), (1.0, 9.0), (0.0, 3.0), (2.0, 11.0), (0.0, 6.0), (0.0, 8.0), (2.0, 13.0)] #, (0.0, 10.0), (0.0, 12.0), (1.0, 14.0)]
#

unit_tests = []

for i in range(10):
    unit_tests.append([(random.randint(0, 3), random.randint(0, 3)) for _ in range(9)])

for test in unit_tests:
    a = 5
    # a = 1 # a;ready scaled here

    # mul;tiply all the points x5 
    og_points = test
    og_points = [(x*a,y*a) for x,y in og_points] #TODO add back

    points = og_points.copy()
    coloring = []

    while points:
        remaining_set, max_set = run_rydberg(points)
        points = remaining_set
        coloring.append(max_set)

    # plot then colored graph
    # fig, ax = plt.subplots()
    print(coloring)
    visualize_colored_groups(coloring)

# %%
example_data = [[(0, 0), (0, 5), (15, 10)], [(5, 0), (0, 10), (15, 15)]]

# %%
import matplotlib.image as mpimg
import networkx as nx
import math
from itertools import combinations
import matplotlib.pyplot as plt

def visualize_colored_groups_with_background(data, background_image_path, shift_x=0, shift_y=0):
    """
    Visualize colored groups of points overlaid on a background image with optional x and y-axis shifts.

    Args:
        data: List of groups of points (e.g., [[(x1, y1), (x2, y2)], [(x3, y3), ...]]).
        background_image_path: Path to the background image.
        shift_x: Value to shift all x-coordinates to the right (default is 0).
        shift_y: Value to shift all y-coordinates upward (default is 0).
    """
    # Load the background image
    img = mpimg.imread(background_image_path)
    
    # Create graph and calculate edges
    G = nx.Graph()
    all_points = [point for group in data for point in group]
    
    # Shift all coordinates by shift_x and shift_y
    shifted_points = [(x + shift_x, y + shift_y) for x, y in all_points]
    
    # Add nodes with position attributes
    for point in shifted_points:
        G.add_node(point, pos=point)
    
    # Create edges based on distance threshold
    threshold = 5 * math.sqrt(2)
    for (p1, p2) in combinations(shifted_points, 2):
        distance = math.hypot(p1[0] - p2[0], p1[1] - p2[1])
        if distance <= threshold:
            G.add_edge(p1, p2)
    
    # Create color mapping
    color_map = []
    color_dict = {}
    for color_idx, group in enumerate(data):
        for point in group:
            shifted_point = (point[0] + shift_x, point[1] + shift_y)
            color_dict[shifted_point] = color_idx
    
    # Create ordered color list based on node order
    for node in G.nodes():
        color_map.append(color_dict[node])
    
    # Draw the graph
    pos = nx.get_node_attributes(G, 'pos')
    plt.figure(figsize=(10, 6))
    
    # Display the background image
    plt.imshow(img, extent=[0, max(p[0] for p in shifted_points) + 10, 0, max(p[1] for p in shifted_points) + 10], aspect='auto')
    
    # Overlay the graph
    nx.draw(G, pos, 
            node_color=color_map, 
            cmap=plt.cm.tab20,
            with_labels=False,
            node_size=500,
            edge_color='gray')
    
    # Add coordinate labels
    for point in shifted_points:
        plt.text(point[0], point[1], f"({point[0]},{point[1]})", 
                 ha='center', va='bottom', fontsize=8)
    
    plt.title("Graph Coloring Visualization with Background\n(Edges: distance < 5√2)")
    plt.grid(True, alpha=0.3)
    plt.show()

# Example usage
visualize_colored_groups_with_background(coloring, "/opt/extra/avijit/projects/rlof/Ryan_2025/YQH/city.png", shift_x=25, shift_y=5)

# %%
provider = QbraidProvider(api_key=api_key)
provider.save_config()
provider = QbraidProvider()
provider.get_devices()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 provider = QbraidProvider(api_key=api_key)
#       2 provider.save_config()
#       3 provider = QbraidProvider()
#
# NameError: name 'QbraidProvider' is not defined
